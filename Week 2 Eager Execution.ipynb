# %%
# !pip install tensorflow==1.3.0
# Out:
# Requirement already satisfied: tensorflow==1.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.3.0)
# Requirement already satisfied: protobuf>=3.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==1.3.0) (3.11.2)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==1.3.0) (0.32.3)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==1.3.0) (1.12.0)
# Requirement already satisfied: tensorflow-tensorboard<0.2.0,>=0.1.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==1.3.0) (0.1.8)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==1.3.0) (1.15.4)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python36/lib/python3.6/site-packages (from protobuf>=3.3.0->tensorflow==1.3.0) (40.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow-tensorboard<0.2.0,>=0.1.0->tensorflow==1.3.0) (3.0.1)
# Requirement already satisfied: html5lib==0.9999999 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow-tensorboard<0.2.0,>=0.1.0->tensorflow==1.3.0) (0.9999999)
# Requirement already satisfied: werkzeug>=0.11.10 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow-tensorboard<0.2.0,>=0.1.0->tensorflow==1.3.0) (0.14.1)
# Requirement already satisfied: bleach==1.5.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow-tensorboard<0.2.0,>=0.1.0->tensorflow==1.3.0) (1.5.0)

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.3.0'

# %%
import numpy as np

# %%
a = tf.constant(np.array([1.,2.,3.]))
type(a)
# Out:
# tensorflow.python.framework.ops.Tensor

# %%
b = tf.constant(np.array([4.,5.,6.]))
type(b)
# Out:
# tensorflow.python.framework.ops.Tensor

# %%
c = tf.tensordot(a,b,1)
type(c)
# Out:
# tensorflow.python.framework.ops.Tensor

# %%
S = tf.Session()
output = S.run(c)
print(output)
# Out:
# 32.0

# %%
# !pip install tensorflow==2.0.0-alpha0
# Out:
# Requirement already satisfied: tensorflow==2.0.0-alpha0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (2.0.0a0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.16.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.0.6)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (0.2.2)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (3.11.2)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.14.0.dev2019030115)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.0.5)
# Requirement already satisfied: tb-nightly<1.14.0a20190302,>=1.14.0a20190301 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.14.0a20190301)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (0.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (0.32.3)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (1.15.4)
# Requirement already satisfied: google-pasta>=0.1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tensorflow==2.0.0-alpha0) (0.2.0)
# Requirement already satisfied: h5py in /opt/conda/envs/Python36/lib/python3.6/site-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-alpha0) (2.9.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python36/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow==2.0.0-alpha0) (40.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0-alpha0) (3.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0-alpha0) (0.14.1)

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0-alpha0'

# %%
import numpy as np

# %%
a = tf.constant(np.array([1.,2.,3.]))
type(a)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
a = tf.constant(np.array([1.,2.,3.]))
type(a)
print(a.numpy())
# Out:
# [1. 2. 3.]

# %%
b = tf.constant(np.array([4.,5.,6.]))
type(b)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
b = tf.constant(np.array([4.,5.,6.]))
type(b)
print(a.numpy())
# Out:
# [1. 2. 3.]

# %%
c = tf.tensordot(a,b,1)
type(c)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
c = tf.tensordot(a,b,1)
type(c)
print(a.numpy())
# Out:
# [1. 2. 3.]

# %%
S = tf.Session()
output = S.run(c)
print(output)
# Out:
# 32.0
